# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/sayannath235/potato-leaf-disease-detection?select=Potato-Leaf

# %% [markdown]
# #### Healthy or Unhealthy Potato leaf image Classification

# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# %pip install tensorflow

# %%
# %pip install keras

# %%
import tensorflow as tf
from tensorflow.keras import models,layers
from PIL import Image

# %% [markdown]
# ### Loading dataset

# %%
IMAGE_SIZE=256 # we will be resizing all the images to 256x256
BATCH_SIZE=32 # we will be using batch gradient descent, 32 images at a time
CHANNELS=3 # Purpose of CHANNELS is to tell the model that the images are colored images,  CHANNELS=3 means colored images
EPOCHS=30 # Number of epochs helps to train the model, 30 epochs means the model will see the entire dataset 30 times

# %%
# loading the dataset 
dataset = tf.keras.preprocessing.image_dataset_from_directory("/Users/beniaminenahid/Documents/Data_Science/Data_Science_Projects/Potato_Plant_Disease/Potato_Leaf", image_size=(IMAGE_SIZE, IMAGE_SIZE), batch_size=BATCH_SIZE, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[12], line 2
#       1 # loading the dataset
# ----> 2 dataset = tf.keras.preprocessing.image_dataset_from_directory("/Users/beniaminenahid/Documents/Data_Science/Data_Science_Projects/Potato_Plant_Disease/Potato_Leaf", image_size=(IMAGE_SIZE, IMAGE_SIZE), batch_size=BATCH_SIZE, shuffle=True)
#
# File /Applications/anaconda3/lib/python3.12/site-packages/keras/src/utils/image_dataset_utils.py:232, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     230 if seed is None:
#     231     seed = np.random.randint(1e6)
# --> 232 image_paths, labels, class_names = dataset_utils.index_directory(
#     233     directory,
# ...

# %%
class_names = dataset.class_names
class_names
# Dataset contains 2 classes, Healthy and Unhealthy
# Out:
# ['Healthy', 'Unhealthy']
